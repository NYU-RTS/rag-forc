# %%
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption

# %%
# The source document
DOC_SOURCE = "https://ml-site.cdn-apple.com/papers/the-illusion-of-thinking.pdf"

# %%
from docling.datamodel.pipeline_options import smolvlm_picture_description

pipeline_options = PdfPipelineOptions()
pipeline_options.do_picture_description = True
pipeline_options.picture_description_options = (
    smolvlm_picture_description  # <-- the model choice
)
pipeline_options.picture_description_options.prompt = (
    "Describe the image in five to ten sentences."
)
pipeline_options.images_scale = 2.0
pipeline_options.generate_picture_images = True

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options,
        )
    }
)

# Convert only 6th page to a DoclingDocument
doc = converter.convert(DOC_SOURCE, page_range=(6,6)).document
# Out:
# Loading weights:   0%|          | 0/471 [00:00<?, ?it/s]
# [INFO] 2026-08-14 11:41:21,023 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-14 11:41:21,026 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-14 11:41:21,031 [RapidOCR] download_file.py:60: File exists and is valid: /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/PP-OCRv6_det_small.pth
# [INFO] 2026-08-14 11:41:21,031 [RapidOCR] main.py:50: Using /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/PP-OCRv6_det_small.pth
# [INFO] 2026-08-14 11:41:21,252 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-14 11:41:21,252 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-14 11:41:21,253 [RapidOCR] download_file.py:60: File exists and is valid: /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-08-14 11:41:21,253 [RapidOCR] main.py:50: Using /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-08-14 11:41:21,292 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-08-14 11:41:21,292 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-08-14 11:41:21,304 [RapidOCR] download_file.py:60: File exists and is valid: /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/PP-OCRv6_rec_small.pth
# [INFO] 2026-08-14 11:41:21,304 [RapidOCR] main.py:50: Using /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/rapidocr/models/PP-OCRv6_rec_small.pth
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/770 [00:00<?, ?it/s]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0] Graph break from `Tensor.item()`, consider setting:
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     torch._dynamo.config.capture_scalar_outputs = True
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0] or:
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     env TORCHDYNAMO_CAPTURE_SCALAR_OUTPUTS=1
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0] to include these operations in the captured graph.
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0] Graph break: from user code at:
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/utils/generic.py", line 900, in wrapper
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     output = func(self, *args, **kwargs)
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py", line 1807, in forward
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     outputs = self.model(
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/utils/generic.py", line 900, in wrapper
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     output = func(self, *args, **kwargs)
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py", line 1571, in forward
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     decoder_outputs = self.decoder(
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/utils/generic.py", line 976, in wrapper
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     output = func(self, *args, **kwargs)
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/utils/output_capturing.py", line 248, in wrapper
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     outputs = func(self, *args, **kwargs)
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py", line 626, in forward
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     hidden_states = decoder_layer(
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py", line 409, in forward
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     hidden_states, _ = self.encoder_attn(
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py", line 185, in forward
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     torch_compilable_check(
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     ^
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]   File "/Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/transformers/utils/import_utils.py", line 1552, in torch_compilable_check
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     torch._check_tensor_all_with(error_type, cond, msg_callable)
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# W0814 11:41:23.922000 11117 torch/_dynamo/variables/tensor.py:1759] [0/0]
# /Users/ss19980/Documents/packages/rag-forc/notebooks/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:560: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Convolution.cpp:1102.)
#   return F.conv2d(

# %%
print(doc.export_to_markdown())
# Out:
# Figure 3: Illustration of the four puzzle environments. Columns show the progression from initial state (top) through intermediate state (middle) to target state (bottom) for puzzles: Tower of Hanoi (disk transfer across pegs), Checkers Jumping (position swapping of colored tokens), River Crossing (transporting entities across a river), and Blocks World (stack reconfiguration).
#
# <!-- image -->
#
# The image is a bar chart titled "Tower of Hanoi Checkers Jumping River Crossing Blocks World." The chart is divided into two main sections: the upper section and the lower section.
#
# ### Upper Section:
# - **Title:** "Tower of Hanoi Checkers Jumping River Crossing Blocks World"
# - **X-Axis:** Labeled as "Initial State" and "Middle State," indicating the starting state of the checkers game.
# - **Y-Axis:** Labeled as "Checkers Jumping River Crossing Blocks World" and "Blocks World," indicating the different blocks of checkers that are being played.
# - **Data Points:**
#   - **Initial State:** 0
#   - **Middle State:** 1
#   - **Blocks World:** 1
#   - **Blocks World:** 1
#   - **Middle State:** 2
#   - **Blocks World:** 2
#   - **Blocks World:** 2
#
# ## 3.1 Puzzle Environments
#
# We evaluate LRM reasoning on four controllable puzzles spanning compositional depth, planning complexity, and distributional settings. The puzzles are defined below and illustrated in Fig. 3. Tower of Hanoi is a puzzle featuring three pegs and n disks of different sizes stacked on the first peg in size order (largest at bottom). The goal is to transfer all disks from the first peg to the third peg. Valid moves include moving only one disk at a time, taking only the top disk from a peg, and never placing a larger disk on top of a smaller one. The difficulty in this task can be controlled by the number of initial disks as the minimum number of required moves with n initial disks will be 2 n -1 . However, in this work we do not grade for optimality of final solution and only measuring the correctness of each move and reaching the target state.
#
# Blocks World is a block-stacking puzzle requiring rearrangement of blocks from an initial configuration into a specified goal configuration. The objective is to find the minimum number of moves needed for this transformation. Valid moves are restricted to the topmost block of any stack, which can be placed either on an empty stack or on top of another block. The complexity in this task can be controlled by the number of blocks present.
#
# Checker Jumping is a one-dimensional puzzle arranging red checkers, blue checkers, and a single empty space in a line. The objective is to swap the positions of all red and blue checkers, effectively mirroring the initial configuration. Valid moves include sliding a checker into an adjacent empty space or jumping over exactly one checker of the opposite color to land in an empty space. No checker can move backward in the puzzle process. The complexity of this task can be controlled by the number of checkers: with 2 n checkers, the minimum number of moves required will be ( n +1) 2 -1 . River Crossing is a constraint satisfaction planning puzzle involving n actors and their corresponding n agents who must cross a river using a boat. The goal is to transport all 2 n individuals from the left bank to the right bank. The boat can carry at most k individuals and cannot travel empty. Invalid situations arise when an actor is in the presence of another agent without their own agent present, as each agent must protect their client from competing agents. The complexity of this task can also be controlled by the number of actor/agent pairs present. For n = 2 , n = 3 pairs, we use boat capacity of k = 2 and for larger number of pairs we use k = 3 .
